# %%
# Importing required modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
# %matplotlib notebook

# %%
df = pd.read_csv('dataset1.csv')

# Replace missing values in all columns with mean values
mean_values = df.mean()
df = df.fillna(mean_values)

# M -> +ve, B -> -ve
df['diagnosis'] = df['diagnosis'].replace({'M': 1, 'B': 0})

#remove the 'id' column
df = df.drop('id', axis=1)

# Move column 'diagnosis' to the end
col = df.pop('diagnosis')
df.insert(len(df.columns), 'diagnosis', col)

# Rename column 'diagnosis' to 'Class'
#df = df.rename(columns={'diagnosis': 'Class'})

num_data, num_columns = df.shape
num_features = num_columns - 1
head = [f'feature {i}' for i in range(1, num_columns)] + ['Class']
df.columns = head
df

df
# Out:
#      feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 0        17.99      10.38     122.80     1001.0    0.11840    0.27760
# 1        20.57      17.77     132.90     1326.0    0.08474    0.07864
# 2        19.69      21.25     130.00     1203.0    0.10960    0.15990
# 3        11.42      20.38      77.58      386.1    0.14250    0.28390
# 4        20.29      14.34     135.10     1297.0    0.10030    0.13280
# ..         ...        ...        ...        ...        ...        ...
# 564      21.56      22.39     142.00     1479.0    0.11100    0.11590
# 565      20.13      28.25     131.20     1261.0    0.09780    0.10340
# 566      16.60      28.08     108.30      858.1    0.08455    0.10230
# 567      20.60      29.33     140.10     1265.0    0.11780    0.27700
# 568       7.76      24.54      47.92      181.0    0.05263    0.04362
#
#      feature 7  feature 8  feature 9  feature 10  ...  feature 22  feature 23  \
# 0      0.30010    0.14710     0.2419     0.07871  ...       17.33      184.60
# 1      0.08690    0.07017     0.1812     0.05667  ...       23.41      158.80
# 2      0.19740    0.12790     0.2069     0.05999  ...       25.53      152.50
# 3      0.24140    0.10520     0.2597     0.09744  ...       26.50       98.87
# 4      0.19800    0.10430     0.1809     0.05883  ...       16.67      152.20
# ..         ...        ...        ...         ...  ...         ...         ...
# 564    0.24390    0.13890     0.1726     0.05623  ...       26.40      166.10
# 565    0.14400    0.09791     0.1752     0.05533  ...       38.25      155.00
# 566    0.09251    0.05302     0.1590     0.05648  ...       34.12      126.70
# 567    0.35140    0.15200     0.2397     0.07016  ...       39.42      184.60
# 568    0.00000    0.00000     0.1587     0.05884  ...       30.37       59.16
#
#      feature 24  feature 25  feature 26  feature 27  feature 28  feature 29  \
# 0        2019.0     0.16220     0.66560      0.7119      0.2654      0.4601
# 1        1956.0     0.12380     0.18660      0.2416      0.1860      0.2750
# 2        1709.0     0.14440     0.42450      0.4504      0.2430      0.3613
# 3         567.7     0.20980     0.86630      0.6869      0.2575      0.6638
# 4        1575.0     0.13740     0.20500      0.4000      0.1625      0.2364
# ..          ...         ...         ...         ...         ...         ...
# 564      2027.0     0.14100     0.21130      0.4107      0.2216      0.2060
# 565      1731.0     0.11660     0.19220      0.3215      0.1628      0.2572
# 566      1124.0     0.11390     0.30940      0.3403      0.1418      0.2218
# 567      1821.0     0.16500     0.86810      0.9387      0.2650      0.4087
# 568       268.6     0.08996     0.06444      0.0000      0.0000      0.2871
#
#      feature 30  Class
# 0       0.11890      1
# 1       0.08902      1
# 2       0.08758      1
# 3       0.17300      1
# 4       0.07678      1
# ..          ...    ...
# 564     0.07115      1
# 565     0.06637      1
# 566     0.07820      1
# 567     0.12400      1
# 568     0.07039      0
#
# [569 rows x 31 columns]

# %%
# define the columns to be normalized
cols_to_normalize = [f'feature {i}' for i in range(1, num_columns)]

# normalize the selected columns using NumPy
df[cols_to_normalize] = (df[cols_to_normalize] - df[cols_to_normalize].mean()) / df[cols_to_normalize].std()

df
# Out:
#      feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 0     1.102422  -2.071512   1.268389   0.983510   1.567087   3.280628
# 1     1.836635  -0.353322   1.684639   1.907030  -0.826235  -0.486643
# 2     1.586206   0.455786   1.565122   1.557513   0.941382   1.052000
# 3    -0.767260   0.253509  -0.595257  -0.763792   3.280667   3.399917
# 4     1.756953  -1.150804   1.775308   1.824624   0.280125   0.538866
# ..         ...        ...        ...        ...        ...        ...
# 564   2.118368   0.720838   2.059677   2.341795   1.040926   0.218868
# 565   1.711420   2.083301   1.614577   1.722326   0.102368  -0.017817
# 566   0.706858   2.043775   0.670803   0.577445  -0.839745  -0.038646
# 567   1.845172   2.334403   1.981372   1.733693   1.524426   3.269267
# 568  -1.808817   1.220718  -1.817631  -1.346604  -3.109349  -1.149741
#
#      feature 7  feature 8  feature 9  feature 10  ...  feature 22  feature 23  \
# 0     2.650837   2.530249   2.215566    2.253764  ...   -1.358098    2.301575
# 1    -0.025417   0.547662   0.001391   -0.867889  ...   -0.368879    1.533776
# 2     1.361666   2.035440   0.938859   -0.397658  ...   -0.023953    1.346291
# 3     1.913989   1.450431   2.864862    4.906602  ...    0.133866   -0.249720
# 4     1.369198   1.427237  -0.009552   -0.561956  ...   -1.465481    1.337363
# ..         ...        ...        ...         ...  ...         ...         ...
# 564   1.945370   2.318924  -0.312314   -0.930209  ...    0.117596    1.751022
# 565   0.691347   1.262558  -0.217473   -1.057681  ...    2.045599    1.420690
# 566   0.045004   0.105684  -0.808406   -0.894800  ...    1.373645    0.578492
# 567   3.294795   2.656528   2.135315    1.042778  ...    2.235958    2.301575
# 568  -1.116254  -1.260710  -0.819349   -0.560539  ...    0.763518   -1.431475
#
#      feature 24  feature 25  feature 26  feature 27  feature 28  feature 29  \
# 0      1.998658    1.306537    2.614365    2.107374    2.294058    2.748204
# 1      1.887973   -0.375282   -0.430066   -0.147968    1.086129   -0.243675
# 2      1.454016    0.526944    1.081980    0.853340    1.953282    1.151242
# 3     -0.551147    3.391291    3.889975    1.987485    2.173873    6.040726
# 4      1.218589    0.220362   -0.313119    0.611645    0.728618   -0.867590
# ..          ...         ...         ...         ...         ...         ...
# 564    2.012713    0.378033   -0.273077    0.662958    1.627719   -1.358963
# 565    1.492668   -0.690623   -0.394473    0.235195    0.733182   -0.531387
# 566    0.426222   -0.808876    0.350427    0.325352    0.413705   -1.103578
# 567    1.650790    1.429169    3.901415    3.195002    2.287972    1.917396
# 568   -1.076640   -1.857384   -1.206491   -1.306570   -1.743529   -0.048096
#
#      feature 30  Class
# 0      1.935312      1
# 1      0.280943      1
# 2      0.201214      1
# 3      4.930672      1
# 4     -0.396751      1
# ..          ...    ...
# 564   -0.708467      1
# 565   -0.973122      1
# 566   -0.318129      1
# 567    2.217684      1
# 568   -0.750546      0
#
# [569 rows x 31 columns]

# %%
# shuffle feature columns while retaining the original feature names
columns_to_shuffle = [f'feature {i}' for i in range(1, num_columns)]
shuffled_columns = df[columns_to_shuffle].sample(frac=1, axis=1)
#shuffled_columns = shuffled_columns.reindex(columns=columns_to_shuffle)
#shuffled_columns
df[columns_to_shuffle] = shuffled_columns.values
df
# Out:
#      feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 0    -0.213814   2.748204   2.530249   1.567087   1.316568   1.998658
# 1    -0.604819  -0.243675   0.547662  -0.826235  -0.691723   1.887973
# 2    -0.296744   1.151242   2.035440   0.941382   0.815054   1.454016
# 3     0.689095   6.040726   1.450431   3.280667   2.742924  -0.551147
# 4     1.481763  -0.867590   1.427237   0.280125  -0.047796   1.218589
# ..         ...        ...        ...        ...        ...        ...
# 564   1.085429  -1.358963   2.318924   1.040926   0.192350   2.012713
# 565  -0.423637  -0.531387   1.262558   0.102368  -0.069018   1.492668
# 566  -0.379008  -1.103578   0.105684  -0.839745   0.661472   0.426222
# 567  -0.172848   1.917396   2.656528   1.524426   2.016901   1.650790
# 568   0.049299  -0.048096  -1.260710  -3.109349  -1.161962  -1.076640
#
#      feature 7  feature 8  feature 9  feature 10  ...  feature 22  feature 23  \
# 0     0.723390   2.830540   1.935312    0.906286  ...    2.485391    2.301575
# 1    -0.440393   0.263095   0.280943   -0.099356  ...    0.741749    1.533776
# 2     0.212889   0.850180   0.201214    0.293301  ...    1.180298    1.346291
# 3     0.818798   0.286341   4.930672    2.045711  ...   -0.288125   -0.249720
# 4     0.827742   1.272070  -0.396751    0.498889  ...    1.189310    1.337363
# ..         ...        ...        ...         ...  ...         ...         ...
# 564   0.665416   2.377491  -0.708467    0.167832  ...    2.601897    1.751022
# 565   0.251980   1.155840  -0.973122   -0.490124  ...    1.290429    1.420690
# 566   0.510377   0.276450  -0.318129    0.036694  ...    0.180539    0.578492
# 567   1.301140   1.437265   2.217684    0.903262  ...    1.008615    2.301575
# 568  -1.056571  -0.157311  -0.750546   -0.382418  ...   -0.465742   -1.431475
#
#      feature 24  feature 25  feature 26  feature 27  feature 28  feature 29  \
# 0      3.280628   -2.071512    1.102422    2.614365    1.268389    2.487545
# 1     -0.486643   -0.353322    1.836635   -0.430066    1.684639    0.498816
# 2      1.052000    0.455786    1.586206    1.081980    1.565122    1.227596
# 3      3.399917    0.253509   -0.767260    3.889975   -0.595257    0.326087
# 4      0.538866   -1.150804    1.756953   -0.313119    1.775308    1.269426
# ..          ...         ...         ...         ...         ...         ...
# 564    0.218868    0.720838    2.118368   -0.273077    2.059677    2.779634
# 565   -0.017817    2.083301    1.711420   -0.394473    1.614577    1.299356
# 566   -0.038646    2.043775    0.706858    0.350427    0.670803    0.184730
# 567    3.269267    2.334403    1.845172    3.901415    1.981372    1.156917
# 568   -1.149741    1.220718   -1.808817   -1.206491   -1.817631   -0.070217
#
#      feature 30  Class
# 0      0.660239      1
# 1      0.259933      1
# 2      1.423575      1
# 3      1.114027      1
# 4      1.143199      1
# ..          ...    ...
# 564    2.065360      1
# 565    0.807720      1
# 566    0.611619      1
# 567    0.785031      1
# 568   -1.911765      0
#
# [569 rows x 31 columns]

# %% [markdown]
# # Training and testing data split

# %%
# set a random seed for reproducibility
random_seed = 42

# randomly shuffle the rows of the DataFrame
df = df.sample(frac=1, random_state=random_seed)

# split the DataFrame into training and testing sets
train_size = int(0.67 * len(df))  # set the fraction of data to use for training
train_df = df[:train_size]  # take the first train_size rows for training
test_df = df[train_size:]  # take the remaining rows for testing
train_df
# Out:
#      feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 204  -0.029302   0.183043  -0.275989   0.233908  -0.354960  -0.357536
# 70   -0.864934  -0.565331   0.788366  -0.445835  -0.499606   1.729851
# 131  -0.266769  -0.103052   0.823415   0.912941  -0.593430   0.482444
# 431   0.985513  -0.557249  -0.539371   0.642750   0.417975  -0.642331
# 540   1.701579  -0.924162  -0.592203   0.247418   0.874253  -0.744232
# ..         ...        ...        ...        ...        ...        ...
# 437   0.311412  -0.284084  -0.502003  -0.837612  -0.698983  -0.230863
# 258   1.771520   0.608146   2.287999   1.033816   1.925869   0.605427
# 232  -0.893243   0.016558  -1.094898  -1.319689  -1.041722  -0.721216
# 115   0.253794  -0.747979  -0.743222   0.093836  -0.022106  -0.524267
# 120  -0.333380   0.186276  -0.584729  -0.187021  -0.568299  -0.651643
#
#      feature 7  feature 8  feature 9  feature 10  ...  feature 22  feature 23  \
# 204  -0.161787  -0.182535   0.196785   -0.078949  ...   -0.220859   -0.333642
# 70   -0.304900   1.295811  -0.999698   -0.792459  ...    1.224702    1.745070
# 131  -0.124684   0.112738  -0.207949   -0.504107  ...    0.175264    0.524924
# 431   0.553775  -0.327451   0.533970    0.835237  ...   -0.547517   -0.525294
# 540   0.783020  -0.612338  -0.144277    0.648923  ...   -0.428152   -0.847591
# ..         ...        ...        ...         ...  ...         ...         ...
# 437  -0.523875  -0.109829  -0.642580   -0.364655  ...   -0.167002   -0.180380
# 258   1.670516   3.587766   0.994071    0.849220  ...    2.157853    1.084406
# 232  -0.949800  -0.681087  -0.602162   -0.476519  ...   -0.546857   -0.857709
# 115  -0.448675  -0.428349   0.081068    0.023089  ...   -0.341762   -0.586896
# 120  -0.555015  -0.872001   0.071101   -0.600477  ...   -0.655890   -0.699983
#
#      feature 24  feature 25  feature 26  feature 27  feature 28  feature 29  \
# 204    0.027626   -0.160345   -0.468452   -0.104649   -0.450600   -0.032714
# 70    -0.027285    0.469736    1.372772   -0.131343    1.301360    1.383377
# 131    0.340051    0.044257    0.382438   -0.094479    0.398798    0.249278
# 431    0.516145   -0.374247   -0.488372    0.054882   -0.434939   -0.823879
# 540    0.145022   -1.127554   -0.733110   -0.269900   -0.716011   -0.457145
# ..          ...         ...         ...         ...         ...         ...
# 437   -0.859470   -0.769500   -0.021664   -0.820312   -0.092460   -0.057596
# 258    3.920625    0.909165    0.439354    1.671163    0.749107    3.197934
# 232   -1.298947    3.376013   -0.824175   -1.178462   -0.875092   -0.653674
# 115   -0.489484    0.520887   -0.622124   -0.091301   -0.638530   -0.336703
# 120   -0.709885   -1.969211   -0.770105   -0.097022   -0.769999   -0.953335
#
#      feature 30  Class
# 204   -0.231130      0
# 70     0.308553      1
# 131   -0.140372      1
# 431   -0.020443      0
# 540    0.509517      0
# ..          ...    ...
# 437   -0.445707      0
# 258    2.989143      1
# 232   -1.357658      0
# 115   -0.662066      0
# 120   -0.864812      0
#
# [381 rows x 31 columns]

# %% [markdown]
# # Generating Features and Class array

# %%
positive_mask = (train_df['Class'] == 1)
pos_points = train_df[positive_mask]
neg_points = train_df[~positive_mask]
num_pos = pos_points.shape[0]
num_neg = neg_points.shape[0]
print(neg_points)
# Out:
#      feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 204  -0.029302   0.183043  -0.275989   0.233908  -0.354960  -0.357536
# 431   0.985513  -0.557249  -0.539371   0.642750   0.417975  -0.642331
# 540   1.701579  -0.924162  -0.592203   0.247418   0.874253  -0.744232
# 81   -0.082257   1.012235   0.539931   0.813397   0.574349  -0.468221
# 477  -1.243283  -0.358437  -0.915633  -1.996589  -0.687813  -0.285502
# ..         ...        ...        ...        ...        ...        ...
# 136  -0.154197  -1.921455  -0.590656   0.621419  -0.651512  -0.588043
# 437   0.311412  -0.284084  -0.502003  -0.837612  -0.698983  -0.230863
# 232  -0.893243   0.016558  -1.094898  -1.319689  -1.041722  -0.721216
# 115   0.253794  -0.747979  -0.743222   0.093836  -0.022106  -0.524267
# 120  -0.333380   0.186276  -0.584729  -0.187021  -0.568299  -0.651643
#
#      feature 7  feature 8  feature 9  feature 10  ...  feature 22  feature 23  \
# 204  -0.161787  -0.182535   0.196785   -0.078949  ...   -0.220859   -0.333642
# 431   0.553775  -0.327451   0.533970    0.835237  ...   -0.547517   -0.525294
# 540   0.783020  -0.612338  -0.144277    0.648923  ...   -0.428152   -0.847591
# 81    0.261918  -0.658336   0.977461    0.305395  ...   -0.601813   -0.315488
# 477  -0.728473  -0.729063  -0.385677   -0.642426  ...   -0.578292   -0.180380
# ..         ...        ...        ...         ...  ...         ...         ...
# 136  -0.174707   0.193852  -0.582230   -0.033221  ...   -0.131171   -0.627965
# 437  -0.523875  -0.109829  -0.642580   -0.364655  ...   -0.167002   -0.180380
# 232  -0.949800  -0.681087  -0.602162   -0.476519  ...   -0.546857   -0.857709
# 115  -0.448675  -0.428349   0.081068    0.023089  ...   -0.341762   -0.586896
# 120  -0.555015  -0.872001   0.071101   -0.600477  ...   -0.655890   -0.699983
#
#      feature 24  feature 25  feature 26  feature 27  feature 28  feature 29  \
# 204    0.027626   -0.160345   -0.468452   -0.104649   -0.450600   -0.032714
# 431    0.516145   -0.374247   -0.488372    0.054882   -0.434939   -0.823879
# 540    0.145022   -1.127554   -0.733110   -0.269900   -0.716011   -0.457145
# 81     0.930817   -0.797401   -0.220869    1.429007   -0.228050   -0.429739
# 477   -0.968535   -0.620699   -0.061505   -0.341085   -0.125842   -0.900327
# ..          ...         ...         ...         ...         ...         ...
# 136   -0.821600   -0.609074   -0.684732   -0.962682   -0.713126    0.157685
# 437   -0.859470   -0.769500   -0.021664   -0.820312   -0.092460   -0.057596
# 232   -1.298947    3.376013   -0.824175   -1.178462   -0.875092   -0.653674
# 115   -0.489484    0.520887   -0.622124   -0.091301   -0.638530   -0.336703
# 120   -0.709885   -1.969211   -0.770105   -0.097022   -0.769999   -0.953335
#
#      feature 30  Class
# 204   -0.231130      0
# 431   -0.020443      0
# 540    0.509517      0
# 81     0.329622      0
# 477   -1.128657      0
# ..          ...    ...
# 136    0.206451      0
# 437   -0.445707      0
# 232   -1.357658      0
# 115   -0.662066      0
# 120   -0.864812      0
#
# [245 rows x 31 columns]

# %% [markdown]
# # Starting LDA

# %%
pos_mean = pos_points.mean().to_numpy().reshape((1, -1))[:, :-1]
neg_mean = neg_points.mean().to_numpy().reshape((1, -1))[:, :-1]
pos_mean
# Out:
# array([[-0.16286608,  0.56950751,  1.04990334,  0.47311216,  0.35837656,
#          1.03842204,  0.27747873,  0.72713871,  0.41046923,  0.06792556,
#          0.53212536,  1.04732374,  0.98076194, -0.05393097, -0.01579337,
#          0.45207401,  0.90994652,  0.83967247,  0.62085562, -0.00922591,
#          1.08940737,  0.71909452,  1.09495065,  0.79499175,  0.57531936,
#          1.00189064,  0.78131833,  1.02154542,  0.76627494,  0.4630725 ]])

# %%
pos_points = pos_points.drop(['Class'], axis=1)
neg_points = neg_points.drop(['Class'], axis=1)
pos_diff = pos_points - pos_mean
neg_diff = neg_points - neg_mean

# %%
pos_diff = pos_diff.to_numpy()
neg_diff = neg_diff.to_numpy()
pos_diff
# Out:
# array([[-0.70206761, -1.13483809, -0.26153707, ...,  0.2798142 ,
#          0.61710166, -0.15451903],
#        [-0.10390299, -0.67255959, -0.22648809, ..., -0.62274774,
#         -0.51699701, -0.60344479],
#        [-0.00998182,  1.34788839,  1.60662492, ...,  0.95982662,
#          0.39064253,  0.32195814],
#        ...,
#        [-0.57650633, -0.71296855, -0.26179478, ...,  0.07787112,
#         -0.77014081, -0.52241126],
#        [-0.34037118, -1.42901532, -0.82154756, ...,  0.02429438,
#          0.0668204 , -0.0345894 ],
#        [ 1.93438625,  0.0386381 ,  1.23809524, ..., -0.27243831,
#          2.43165952,  2.5260702 ]])

# %% [markdown]
# # Getting Covariance Matrix

# %%
pos_sum = np.zeros((num_features, num_features))
neg_sum = np.zeros((num_features, num_features))

for x in pos_diff:
    x = x.reshape((1, -1))
    pos_sum += np.matmul(x.T, x)
for x in neg_diff:
    x = x.reshape((1, -1))
    neg_sum += np.matmul(x.T, x)

cov_matrix = pos_sum / num_pos + neg_sum / num_neg
cov_matrix
# Out:
# array([[ 1.66214949, -0.06471251,  0.23388342,  0.74033932,  0.61596692,
#         -0.22433713,  0.52436863,  0.39308817,  0.22015287,  0.68024487,
#          0.69772744, -0.02692216, -0.18343228,  0.81689563,  0.74019937,
#          0.49194565,  0.37505073,  0.03435007, -0.07667836,  0.80127879,
#         -0.28763165,  0.23164148, -0.25383959,  0.40149209,  0.06039422,
#         -0.26203676,  0.00949848, -0.2225969 ,  0.41242809,  0.58419355],
#        [-0.06471251,  2.1526792 ,  0.2383267 ,  0.64812541,  0.48283981,
#         -0.22488705,  0.31981093, -0.13493937,  1.0992011 ,  0.30114107,
#          0.75326045,  0.48307816, -0.33644352,  1.18156107,  0.98387954,
#          1.4767063 ,  0.44575599,  0.71008922,  0.04194256, -0.33553341,
#         -0.18628523, -0.23024463, -0.11315939,  0.79820897, -0.18957557,
#         -0.32274949,  1.00764105, -0.26009533, -0.21859078,  0.05039144],
#        [ 0.23388342,  0.2383267 ,  1.07329421,  0.69212757,  0.69931052,
#          0.62390043,  0.59801485,  0.64315955,  0.31386298,  0.48666463,
#          0.33154679,  0.77053868,  0.70383105,  0.31219574,  0.47999439,
#          0.57594668,  1.03722339,  0.63593563, -0.13947415,  0.09787893,
#          0.59008066,  0.58134811,  0.64879257,  0.98954917, -0.08791701,
#          0.6519044 ,  0.58282558,  0.70659279,  0.59127587,  0.66089876],
#        [ 0.74033932,  0.64812541,  0.69212757,  1.69351712,  0.51694895,
#         -0.10000719,  0.39088862,  0.23861587,  0.81804756,  0.55222698,
#          1.24729805,  0.51200867, -0.1189759 ,  0.56276043,  1.21248166,
#          1.0231755 ,  0.70592266,  0.47770276, -0.2930099 ,  0.17490568,
#         -0.09774066,  0.11856103, -0.04135834,  0.98132023, -0.38216789,
#         -0.12323798,  0.5976377 , -0.06130665,  0.2305405 ,  0.49572378],
#        [ 0.61596692,  0.48283981,  0.69931052,  0.51694895,  1.80902311,
#          0.04876443,  1.45660268,  0.62896023,  1.06703972,  1.48543747,
#          0.27358635,  0.62310919,  0.11277489,  0.90048692,  1.15022154,
#          0.747688  ,  1.1064104 ,  0.99966622, -0.03465351,  0.40853898,
#          0.0576316 ,  0.35390982,  0.17937854,  1.26791658,  0.0898093 ,
#          0.08949269,  1.13779465,  0.17877424,  0.5053647 ,  1.16577079],
#        [-0.22433713, -0.22488705,  0.62390043, -0.10000719,  0.04876443,
#          1.13370423,  0.03730014,  0.65388385, -0.35000833, -0.14942406,
#         -0.14758498,  0.43744265,  1.03455561, -0.24617508, -0.4648496 ,
#         -0.16061495,  0.43556442,  0.16371633,  0.08266093, -0.14906571,
#          1.00335945,  0.80410418,  0.98538656,  0.24383005,  0.10271009,
#          0.94834253,  0.07819262,  0.93252285,  0.67251194,  0.1033635 ],
#        [ 0.52436863,  0.31981093,  0.59801485,  0.39088862,  1.45660268,
#          0.03730014,  1.9444182 ,  0.48592227,  0.75173862,  1.4051101 ,
#          0.19183653,  0.55443854,  0.10307053,  0.71592736,  0.94096975,
#          0.62470229,  1.16561512,  1.09448208, -0.071611  ,  0.36888736,
#          0.02788646,  0.29546304,  0.11218147,  0.93693759,  0.01830139,
#          0.06700713,  0.74387353,  0.13631376,  0.43890718,  1.29445879],
#        [ 0.39308817, -0.13493937,  0.64315955,  0.23861587,  0.62896023,
#          0.65388385,  0.48592227,  1.14838466, -0.12760787,  0.41383804,
#         -0.10560815,  0.32668316,  0.59832846,  0.47506115,  0.18541533,
#          0.34961336,  0.62246872,  0.18033994, -0.09157365,  0.47182746,
#          0.5660139 ,  0.93287835,  0.62317002,  0.58327527,  0.06381477,
#          0.51767994,  0.15432623,  0.55421957,  1.09981953,  0.6669828 ],
#        [ 0.22015287,  1.0992011 ,  0.31386298,  0.81804756,  1.06703972,
#         -0.35000833,  0.75173862, -0.12760787,  2.09949625,  1.19537807,
#          1.01989327,  0.59627513, -0.49640075,  0.30329993,  1.70462321,
#          0.82708812,  0.68851611,  1.10044333,  0.20279006, -0.15670004,
#         -0.32701593, -0.27099975, -0.23008491,  1.14277495,  0.0258976 ,
#         -0.47846645,  1.48515425, -0.40360434, -0.20712995,  0.35975848],
#        [ 0.68024487,  0.30114107,  0.48666463,  0.55222698,  1.48543747,
#         -0.14942406,  1.4051101 ,  0.41383804,  1.19537807,  1.86164405,
#          0.32111382,  0.38293633, -0.13200364,  0.77951443,  1.34538334,
#          0.67982904,  0.87777331,  0.72803502, -0.05863031,  0.52245575,
#         -0.15768136,  0.20241986, -0.08381356,  0.97191034,  0.04883554,
#         -0.16013477,  0.77284249, -0.08778252,  0.41182724,  1.05369814],
#        [ 0.69772744,  0.75326045,  0.33154679,  1.24729805,  0.27358635,
#         -0.14758498,  0.19183653, -0.10560815,  1.01989327,  0.32111382,
#          1.60725061,  0.48580557, -0.30014828,  0.10332115,  1.0284199 ,
#          0.65384422,  0.41770082,  0.54899881,  0.07044219, -0.15879672,
#         -0.15695641, -0.12869836, -0.11777391,  0.68406608, -0.18450617,
#         -0.30121583,  0.70001523, -0.26417993, -0.11534988,  0.14308593],
#        [-0.02692216,  0.48307816,  0.77053868,  0.51200867,  0.62310919,
#          0.43744265,  0.55443854,  0.32668316,  0.59627513,  0.38293633,
#          0.48580557,  0.87994463,  0.42177131,  0.06116328,  0.47150563,
#          0.4485299 ,  0.80107657,  0.78199658, -0.03260549, -0.25656649,
#          0.4380576 ,  0.27732222,  0.50025991,  0.86146014, -0.10221672,
#          0.41871474,  0.80166257,  0.45779954,  0.24124315,  0.60915299],
#        [-0.18343228, -0.33644352,  0.70383105, -0.1189759 ,  0.11277489,
#          1.03455561,  0.10307053,  0.59832846, -0.49640075, -0.13200364,
#         -0.30014828,  0.42177131,  1.13951925, -0.17093691, -0.55554575,
#         -0.17640992,  0.50746996,  0.14477903, -0.02283419, -0.0921199 ,
#          0.95937217,  0.71977975,  0.94989864,  0.26144754,  0.09111925,
#          1.06152012,  0.00598082,  1.05160943,  0.5940655 ,  0.18875632],
#        [ 0.81689563,  1.18156107,  0.31219574,  0.56276043,  0.90048692,
#         -0.24617508,  0.71592736,  0.47506115,  0.30329993,  0.77951443,
#          0.10332115,  0.06116328, -0.17093691,  2.3159147 ,  0.90295049,
#          1.19758936,  0.54152731,  0.23485046, -0.19528376,  0.78636479,
#         -0.26788572,  0.20171834, -0.19608207,  0.68612403, -0.03585497,
#         -0.23760443,  0.30120193, -0.15676851,  0.40440156,  0.61464792],
#        [ 0.74019937,  0.98387954,  0.47999439,  1.21248166,  1.15022154,
#         -0.4648496 ,  0.94096975,  0.18541533,  1.70462321,  1.34538334,
#          1.0284199 ,  0.47150563, -0.55554575,  0.90295049,  2.09630205,
#          1.17629268,  0.84466219,  0.8243587 , -0.11040156,  0.2973438 ,
#         -0.47019156, -0.09211427, -0.36245266,  1.29396649, -0.16363327,
#         -0.57847353,  1.08352377, -0.47753822,  0.11110999,  0.68392108],
#        [ 0.49194565,  1.4767063 ,  0.57594668,  1.0231755 ,  0.747688  ,
#         -0.16061495,  0.62470229,  0.34961336,  0.82708812,  0.67982904,
#          0.65384422,  0.4485299 , -0.17640992,  1.19758936,  1.17629268,
#          2.07422354,  0.75704121,  0.56269606, -0.19523978,  0.23213349,
#         -0.14754573,  0.15394842, -0.06581867,  1.0564723 , -0.21189063,
#         -0.20104977,  0.72130151, -0.10877721,  0.32455181,  0.53277168],
#        [ 0.37505073,  0.44575599,  1.03722339,  0.70592266,  1.1064104 ,
#          0.43556442,  1.16561512,  0.62246872,  0.68851611,  0.87777331,
#          0.41770082,  0.80107657,  0.50746996,  0.54152731,  0.84466219,
#          0.75704121,  1.31958105,  1.02825686, -0.04033832,  0.21077574,
#          0.4080341 ,  0.4987574 ,  0.50173809,  1.2131893 ,  0.00624206,
#          0.45773888,  0.87554426,  0.53424036,  0.54540273,  0.8744473 ],
#        [ 0.03435007,  0.71008922,  0.63593563,  0.47770276,  0.99966622,
#          0.16371633,  1.09448208,  0.18033994,  1.10044333,  0.72803502,
#          0.54899881,  0.78199658,  0.14477903,  0.23485046,  0.8243587 ,
#          0.56269606,  1.02825686,  1.30477075,  0.15408789, -0.14911001,
#          0.17471333,  0.08691817,  0.27334168,  1.01486496,  0.06655174,
#          0.14615342,  1.18094486,  0.20673455,  0.06769859,  0.61825224],
#        [-0.07667836,  0.04194256, -0.13947415, -0.2930099 , -0.03465351,
#          0.08266093, -0.071611  , -0.09157365,  0.20279006, -0.05863031,
#          0.07044219, -0.03260549, -0.02283419, -0.19528376, -0.11040156,
#         -0.19523978, -0.04033832,  0.15408789,  1.54774253,  0.71982071,
#          0.06290609, -0.07378212,  0.05620985, -0.08349082,  1.41280955,
#         -0.0265173 ,  0.17615666, -0.03286597, -0.10950574, -0.25806682],
#        [ 0.80127879, -0.33553341,  0.09787893,  0.17490568,  0.40853898,
#         -0.14906571,  0.36888736,  0.47182746, -0.15670004,  0.52245575,
#         -0.15879672, -0.25656649, -0.0921199 ,  0.78636479,  0.2973438 ,
#          0.23213349,  0.21077574, -0.14911001,  0.71982071,  1.97810173,
#         -0.20214866,  0.27495922, -0.18565906,  0.09103037,  0.70815211,
#         -0.16436542, -0.24529083, -0.1274271 ,  0.48643852,  0.38474368],
#        [-0.28763165, -0.18628523,  0.59008066, -0.09774066,  0.0576316 ,
#          1.00335945,  0.02788646,  0.5660139 , -0.32701593, -0.15768136,
#         -0.15695641,  0.4380576 ,  0.95937217, -0.26788572, -0.47019156,
#         -0.14754573,  0.4080341 ,  0.17471333,  0.06290609, -0.20214866,
#          0.932964  ,  0.68332751,  0.91830221,  0.25316456,  0.08974194,
#          0.91427514,  0.11032829,  0.89892074,  0.57367609,  0.11112523],
#        [ 0.23164148, -0.23024463,  0.58134811,  0.11856103,  0.35390982,
#          0.80410418,  0.29546304,  0.93287835, -0.27099975,  0.20241986,
#         -0.12869836,  0.27732222,  0.71977975,  0.20171834, -0.09211427,
#          0.15394842,  0.4987574 ,  0.08691817, -0.07378212,  0.27495922,
#          0.68332751,  0.94235436,  0.69034331,  0.36778238,  0.03689583,
#          0.62759343,  0.00894709,  0.64204444,  0.97793556,  0.39280513],
#        [-0.25383959, -0.11315939,  0.64879257, -0.04135834,  0.17937854,
#          0.98538656,  0.11218147,  0.62317002, -0.23008491, -0.08381356,
#         -0.11777391,  0.50025991,  0.94989864, -0.19608207, -0.36245266,
#         -0.06581867,  0.50173809,  0.27334168,  0.05620985, -0.18565906,
#          0.91830221,  0.69034331,  0.93342738,  0.37747711,  0.08157042,
#          0.90532929,  0.22832397,  0.90042451,  0.58786625,  0.18415952],
#        [ 0.40149209,  0.79820897,  0.98954917,  0.98132023,  1.26791658,
#          0.24383005,  0.93693759,  0.58327527,  1.14277495,  0.97191034,
#          0.68406608,  0.86146014,  0.26144754,  0.68612403,  1.29396649,
#          1.0564723 ,  1.2131893 ,  1.01486496, -0.08349082,  0.09103037,
#          0.25316456,  0.36778238,  0.37747711,  1.5615634 , -0.06350726,
#          0.24906071,  1.23804235,  0.35034346,  0.45586678,  0.83178077],
#        [ 0.06039422, -0.18957557, -0.08791701, -0.38216789,  0.0898093 ,
#          0.10271009,  0.01830139,  0.06381477,  0.0258976 ,  0.04883554,
#         -0.18450617, -0.10221672,  0.09111925, -0.03585497, -0.16363327,
#         -0.21189063,  0.00624206,  0.06655174,  1.41280955,  0.70815211,
#          0.08974194,  0.03689583,  0.08157042, -0.06350726,  1.64354346,
#          0.08033927,  0.06376432,  0.07406922,  0.05938868, -0.10469748],
#        [-0.26203676, -0.32274949,  0.6519044 , -0.12323798,  0.08949269,
#          0.94834253,  0.06700713,  0.51767994, -0.47846645, -0.16013477,
#         -0.30121583,  0.41871474,  1.06152012, -0.23760443, -0.57847353,
#         -0.20104977,  0.45773888,  0.14615342, -0.0265173 , -0.16436542,
#          0.91427514,  0.62759343,  0.90532929,  0.24906071,  0.08033927,
#          1.05011546,  0.02799527,  1.01333774,  0.50347302,  0.17296957],
#        [ 0.00949848,  1.00764105,  0.58282558,  0.5976377 ,  1.13779465,
#          0.07819262,  0.74387353,  0.15432623,  1.48515425,  0.77284249,
#          0.70001523,  0.80166257,  0.00598082,  0.30120193,  1.08352377,
#          0.72130151,  0.87554426,  1.18094486,  0.17615666, -0.24529083,
#          0.11032829,  0.00894709,  0.22832397,  1.23804235,  0.06376432,
#          0.02799527,  1.55130914,  0.10054046,  0.00875865,  0.4743358 ],
#        [-0.2225969 , -0.26009533,  0.70659279, -0.06130665,  0.17877424,
#          0.93252285,  0.13631376,  0.55421957, -0.40360434, -0.08778252,
#         -0.26417993,  0.45779954,  1.05160943, -0.15676851, -0.47753822,
#         -0.10877721,  0.53424036,  0.20673455, -0.03286597, -0.1274271 ,
#          0.89892074,  0.64204444,  0.90042451,  0.35034346,  0.07406922,
#          1.01333774,  0.10054046,  1.01565505,  0.53151218,  0.23356847],
#        [ 0.41242809, -0.21859078,  0.59127587,  0.2305405 ,  0.5053647 ,
#          0.67251194,  0.43890718,  1.09981953, -0.20712995,  0.41182724,
#         -0.11534988,  0.24124315,  0.5940655 ,  0.40440156,  0.11110999,
#          0.32455181,  0.54540273,  0.06769859, -0.10950574,  0.48643852,
#          0.57367609,  0.97793556,  0.58786625,  0.45586678,  0.05938868,
#          0.50347302,  0.00875865,  0.53151218,  1.16278519,  0.59268511],
#        [ 0.58419355,  0.05039144,  0.66089876,  0.49572378,  1.16577079,
#          0.1033635 ,  1.29445879,  0.6669828 ,  0.35975848,  1.05369814,
#          0.14308593,  0.60915299,  0.18875632,  0.61464792,  0.68392108,
#          0.53277168,  0.8744473 ,  0.61825224, -0.25806682,  0.38474368,
#          0.11112523,  0.39280513,  0.18415952,  0.83178077, -0.10469748,
#          0.17296957,  0.4743358 ,  0.23356847,  0.59268511,  1.49354275]])

# %%
cov_matrix.shape
# Out:
# (30, 30)

# %% [markdown]
# # Getting Weight Array

# %%
w = np.matmul(np.linalg.inv(cov_matrix), (pos_mean - neg_mean).T)
w = w / np.linalg.norm(w)
w
# Out:
# array([[ 0.03235886],
#        [ 0.03004852],
#        [ 0.03906184],
#        [ 0.00730442],
#        [-0.0007842 ],
#        [-0.56259821],
#        [-0.08348073],
#        [-0.18304311],
#        [ 0.1464273 ],
#        [-0.06173566],
#        [ 0.0121644 ],
#        [ 0.07135753],
#        [-0.0510589 ],
#        [ 0.02535336],
#        [-0.02044448],
#        [-0.00373752],
#        [ 0.03472199],
#        [ 0.11286042],
#        [ 0.02551657],
#        [ 0.01426785],
#        [ 0.65414367],
#        [-0.06289458],
#        [ 0.17826701],
#        [-0.13540325],
#        [ 0.03113563],
#        [-0.04031705],
#        [-0.09954372],
#        [ 0.05057987],
#        [ 0.29747706],
#        [ 0.07057209]])

# %%
w.shape
# Out:
# (30, 1)

# %%
# Finding projection of classes
project_pos = np.dot(pos_points.to_numpy(), w.flatten())
project_neg = np.dot(neg_points.to_numpy(), w.flatten())
print(project_pos.shape)
# Out:
# (136,)

# %% [markdown]
# # Function to find intersection of two normal curves

# %%
def solve(m1,m2,std1,std2):
    a = 1/(2*std1**2) - 1/(2*std2**2)
    b = m2/(std2**2) - m1/(std1**2)
    c = m1**2 /(2*std1**2) - m2**2 / (2*std2**2) - np.log(std2/std1)
    return np.roots([a,b,c])

# %% [markdown]
# # Finding the Intersection

# %%
positive_mean = project_pos.mean()
negative_mean = project_neg.mean()
positive_std = project_pos.std()
negative_std = project_neg.std()

result = solve(positive_mean, negative_mean, positive_std, negative_std)
result = result[1]

# %% [markdown]
# # Visualizing the results

# %%
arrp = np.zeros((len(project_pos)))
arrn = np.zeros((len(project_neg)))

plt.figure(figsize = (10,7))
plt.title(f'Threshold Value: {result}')
plt.scatter(project_pos, arrp, color = 'red', label = 'positive point')
plt.scatter(project_neg, arrn, color = 'blue', label = 'negative point')
yp = np.linspace(-0.1, 0.1, 1000)
xp = result * np.ones((1000))
plt.plot(xp, yp*1000, color = 'green', label = 'Threshold value')
plt.ylim(-0.1, 0.1)
plt.xlim(-2, 2.5)
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
x = np.linspace(-5, 5, 500)
ptemp = np.zeros((len(project_pos), 1))
ntemp = np.zeros((len(project_neg), 1))

plt.figure(figsize = (10,7))
plt.title(f'Threshold Value: {result}')
plt.plot(x, norm.pdf(x, positive_mean, positive_std), color = 'red', label = 'Positive point')
plt.plot(x, norm.pdf(x, negative_mean, negative_std), color = 'blue', label = 'Negative point')

plt.scatter(project_pos, ptemp, color = 'red')
plt.scatter(project_neg, ntemp ,color = 'blue')

yp = np.linspace(-0.1, 0.1, 1000)
xp = result * np.ones((1000))
plt.plot(xp, yp*1000, color = 'green', label = 'Threshold value')
plt.ylim(-0.1, 2.5)
plt.xlim(-2, 2.5)
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# #  Testing the model with training and testing data

# %%
pred_pos_dataset = pd.DataFrame(project_pos)
pred_neg_dataset = pd.DataFrame(project_neg)

pred_pos_dataset = pred_pos_dataset.values
pred_neg_dataset = pred_neg_dataset.values

ptemp = np.zeros((len(pred_pos_dataset), 1))
ntemp = np.zeros((len(pred_neg_dataset), 1))
pred_pos = np.append(pred_pos_dataset, ptemp, axis=1)
pred_neg = np.append(pred_neg_dataset, ntemp, axis=1)

tp=0
tn=0
fp=0
fn=0
for i in range(len(pred_pos_dataset)):
  if pred_pos[i, 0] < result:
    pred_pos[i, 1] = 0
    fn+=1
  else:
    pred_pos[i, 1] = 1
    tp+=1

for i in range(len(pred_neg_dataset)):
  if pred_neg[i, 0] < result:
    pred_neg[i, 1] = 0
    tn+=1
  else:
    pred_neg[i, 1] = 1
    fp+=1

accuracy = (tp+tn)/(tp+tn+fp+fn)
Recall = tp/ (tp + fn)
Precision = tp/ (tp + fp)
print(f'Accuracy of the model with testing is {accuracy * 100}')
print(f'Recall of the model with testing is {Recall * 100}')
print(f'Precision of the model with testing is {Precision * 100}')
# Out:
# Accuracy of the model with testing is 97.3753280839895
# Recall of the model with testing is 94.11764705882352
# Precision of the model with testing is 98.46153846153847

# %%
positive_mask = (test_df['Class'] == 1)
pos_points = test_df[positive_mask]
neg_points = test_df[~positive_mask]
num_pos = pos_points.shape[0]
num_neg = neg_points.shape[0]
print(neg_points.shape)
# Out:
# (112, 31)

# %%
pos_points = pos_points.drop(['Class'], axis=1)
neg_points = neg_points.drop(['Class'], axis=1)

# %%
# Finding projection of classes
project_pos = np.dot(pos_points.to_numpy(), w.flatten())
project_neg = np.dot(neg_points.to_numpy(), w.flatten())
print(project_pos)
# Out:
# [ 0.46546247  0.3366026   0.55426028  0.24865036  0.26491838  0.21166944
#   0.73969493  0.25804577  0.11690911  0.60152608  0.56542835  0.6869738
#   0.42744701  0.08458258  0.03082597  0.36373557  0.74342213  0.67811469
#   0.75507272  0.44704865  0.51664899  0.17689579  0.24723433  0.19441064
#   0.33251408  0.10324432  0.46596591  0.62970644  0.83410841  0.54156468
#   0.6064463   0.464161    0.61549803  0.79742047  0.47726832  0.92787494
#   0.3509841   0.03715751  0.207409    0.46735168  0.88516249  0.13730356
#   0.29809268 -0.03108672  0.13931482  0.68208066  0.82843665  0.29056147
#   0.45930109  0.34396815  0.22498788  0.39192316  0.55268821  0.29604226
#   0.07688535  0.6645185   0.51237789  0.59845431  0.57879278  0.16999398
#   0.50881799  0.90201809  0.15244195  0.7820947   0.11799133  0.70928938
#   1.02602317  0.22992519  0.80211488  0.15729784  0.41532519  1.05681693
#   0.25260035  0.61103446  0.57430637  0.39102666]

# %%
pred_pos_dataset = pd.DataFrame(project_pos)
pred_neg_dataset = pd.DataFrame(project_neg)

pred_pos_dataset = pred_pos_dataset.values
pred_neg_dataset = pred_neg_dataset.values

ptemp = np.zeros((len(pred_pos_dataset), 1))
ntemp = np.zeros((len(pred_neg_dataset), 1))
pred_pos = np.append(pred_pos_dataset, ptemp, axis=1)
pred_neg = np.append(pred_neg_dataset, ntemp, axis=1)

tp=0
tn=0
fp=0
fn=0
for i in range(len(pred_pos_dataset)):
  if pred_pos[i, 0] < result:
    pred_pos[i, 1] = 0
    fn+=1
  else:
    pred_pos[i, 1] = 1
    tp+=1

for i in range(len(pred_neg_dataset)):
  if pred_neg[i, 0] < result:
    pred_neg[i, 1] = 0
    tn+=1
  else:
    pred_neg[i, 1] = 1
    fp+=1

accuracy = (tp+tn)/(tp+tn+fp+fn)
Recall = tp/ (tp + fn)
Precision = tp/ (tp + fp)
print(f'Accuracy of the model with testing is {accuracy * 100}')
print(f'Recall of the model with testing is {Recall * 100}')
print(f'Precision of the model with testing is {Precision * 100}')
# Out:
# Accuracy of the model with testing is 96.80851063829788
# Recall of the model with testing is 94.73684210526315
# Precision of the model with testing is 97.2972972972973
